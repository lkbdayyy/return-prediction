# %% [markdown]
# # 🤖 04. Machine Learning Modeling
# Xác định các yếu tố ảnh hưởng nhất.

# %%
import matplotlib.pyplot as plt
# Biểu đồ Feature Importance
plt.title('Yếu tố nào ảnh hưởng nhất?')
plt.show()
