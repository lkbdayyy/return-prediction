# %% [markdown]
# # 04. Xây dựng Mô hình Dự báo
# **Mô tả:** Huấn luyện Random Forest và XGBoost.
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('--- Đang tải dữ liệu và thư viện phân tích ---')
