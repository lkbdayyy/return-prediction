# %% [markdown]
# # 🤖 04. Machine Learning Modeling
# ### Yếu tố ảnh hưởng đến việc trả hàng
# ![Feature Importance](../outputs/feature_importance.png)

# %%
from sklearn.ensemble import RandomForestClassifier
# model.fit(X, y)
