# %% [markdown]
# # 05. Phân tích Chuỗi thời gian
# **Mô tả:** Theo dõi biến động tỷ lệ trả hàng theo thời gian.
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('--- Đang tải dữ liệu và thư viện phân tích ---')
