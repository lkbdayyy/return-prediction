# %% [markdown]
# # 06. Báo cáo đánh giá mô hình
# **Mô tả:** Chi tiết về Confusion Matrix và hướng tối ưu doanh nghiệp.
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('--- Đang tải dữ liệu và thư viện phân tích ---')
