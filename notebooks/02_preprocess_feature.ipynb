# %% [markdown]
# # 🛠 02. Tiền xử lý dữ liệu

# %%
from sklearn.preprocessing import LabelEncoder
df_model = df[['payment_value', 'item_count', 'customer_state', 'is_return']].dropna()
le = LabelEncoder()
df_model['customer_state'] = le.fit_transform(df_model['customer_state'])
df_model.head()
