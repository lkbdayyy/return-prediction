# %% [markdown]
# # 02. Tiền xử lý & Kỹ thuật đặc trưng
# **Mô tả:** Xử lý dữ liệu khuyết thiếu, Outliers và chuẩn hóa dữ liệu.
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('--- Đang tải dữ liệu và thư viện phân tích ---')
