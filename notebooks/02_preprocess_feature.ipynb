# %% [markdown]
# # 3. Thống Kê Trước Tiền Xử Lý
# Trước khi xử lý, hãy xem tình trạng dữ liệu hiện tại.

# %%
# Overview before cleaning
print('='*70)
print('📊 THỐNG KÊ TRƯỚC TIỀN XỬ LÝ')
print('='*70)
print('Shape: 119,390 rows x 32 columns')
print('Target Distribution (is_canceled):')
print('- Not Canceled (0): 75,166 (62.96%)')
print('- Canceled (1): 44,224 (37.04%)')
print('Missing Values Total: 129,425')
