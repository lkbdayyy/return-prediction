# %% [markdown]
# # 03. Khai phá dữ liệu & Phân cụm
# **Mô tả:** Sử dụng K-Means để phân nhóm khách hàng hay trả hàng.
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('--- Đang tải dữ liệu và thư viện phân tích ---')
